# %% [markdown]
# 1️⃣ Workshop: สร้าง Neuron ด้วย Python
# - มาลองเขียนโค้ด Neuron Model ง่าย ๆ กัน!

# %% [markdown]
# Install python library

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Create Sigmoid Function

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# ทดสอบการทำงาน
x = np.linspace(-10, 10, 100)
y = sigmoid(x)

plt.plot(x, y)
plt.title("Sigmoid Activation Function")
plt.show()

# %% [markdown]
# Create Neuron

# %%
class Neuron:
    def __init__(self, input_size):
        self.weights = np.random.rand(input_size)
        self.bias = np.random.rand()

    def forward(self, x):
        z = np.dot(x, self.weights) + self.bias
        return sigmoid(z)

# ทดสอบโมเดล
Neuron = Neuron(3)  # มี 3 อินพุต
X_sample = np.array([0.5, 0.3, 0.7])
output = Neuron.forward(X_sample)
print(f"Output: {output}")
# Out:
# Output: 0.8870647582178275

# %% [markdown]
# Test : data input 5 values

# %%
class Neuron:
    def __init__(self, input_size):
        self.weights = np.random.rand(input_size)
        self.bias = np.random.rand()

    def forward(self, x):
        z = np.dot(x, self.weights) + self.bias
        return sigmoid(z)

# ทดสอบโมเดล
Neuron = Neuron(5)  # มี 5 อินพุต
X_sample = np.array([0.5, 0.3, 0.7 ,0.2,0.9])
output = Neuron.forward(X_sample)
print(f"Output: {output}")
# Out:
# Output: 0.867197192808917

# %% [markdown]
# Create ReLU Function

# %%
def relu(x):
    return np.maximum(0, x)

x = np.linspace(-10, 10, 100)
y = relu(x)

plt.plot(x, y)
plt.title("ReLU Activation Function")
plt.show()

# %%
class Neuron_ReLU:
    def __init__(self,input_size):
        self.weights = np.random.rand(input_size)
        self.bias = np.random.rand()
        
    def forward(self,x):
        z = np.dot(x,self.weights) + self.bias
        return relu(z)

Neuron2 = Neuron_ReLU(3)  # มี 5 อินพุต
X_sample = np.array([0.5, 0.3, 0.7])
output = Neuron2.forward(X_sample)
print(f"Output: {output}")
# Out:
# Output: 1.3236902742544716

# %%
class NeuronManualWeights:
    def __init__(self):
        self.weights = np.array([0.2, -0.5, 0.9])  # กำหนดค่า Weights เอง
        self.bias = 0.4  # กำหนดค่า Bias เอง

    def forward(self, x):
        z = np.dot(x, self.weights) + self.bias
        return sigmoid(z)

# ทดสอบโมเดล
Neuron_manual = NeuronManualWeights()
X_sample = np.array([0.5, 0.3, 0.7])  # อินพุต
output = Neuron_manual.forward(X_sample)
print(f"Output with Manual Weights: {output}")
# Out:
# Output with Manual Weights: 0.7271082163411295
